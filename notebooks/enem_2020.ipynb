# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd

from utils import load_data_year, load_parquets, info_sum_isna, add_ses_income, add_ses_points

# %% [markdown]
# # Loading the dataset

# %%
cols_used = ['NU_INSCRICAO', 'NU_ANO', 'NO_MUNICIPIO_RESIDENCIA', 'SG_UF_RESIDENCIA',
             'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
             'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA',
             'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
             'TP_PRESENCA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
             'NU_NOTA_MT', 'NU_NOTA_COMP1',
             'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
             'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
             'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
             'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
             'Q023', 'Q024', 'Q025']

# %%
df = load_data_year(2020, cols_used)

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 0  2.000063e+11  2020.0                   Belém               PA      11.0
# 1  2.000012e+11  2020.0                   Natal               RN      11.0
# 2  2.000019e+11  2020.0                Salvador               BA       4.0
# 3  2.000019e+11  2020.0     Santana de Parnaíba               SP       2.0
# 4  2.000016e+11  2020.0              Diamantina               MG       4.0
#
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0       F              1.0          2.0              1.0             11.0
# 1       M              2.0          3.0              1.0             11.0
# 2       F              2.0          3.0              2.0              0.0
# 3       M              1.0          3.0              2.0              0.0
# 4       F              1.0          3.0              1.0              1.0
#
#    ...  Q016  Q017  Q018  Q019  Q020  Q021  Q022  Q023  Q024  Q025
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...     B     A     A     B     A     A     A     A     A     A
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...     A     A     A     B     A     B     B     A     A     B
#
# [5 rows x 50 columns]

# %% [markdown]
# # Pre-processing

# %%
info_sum_isna(df)
# Out:
#                            types  missing
# NU_INSCRICAO             float64        0
# NU_ANO                   float64        0
# NO_MUNICIPIO_RESIDENCIA   object        0
# SG_UF_RESIDENCIA          object        0
# NU_IDADE                 float64        0
# TP_SEXO                   object        0
# TP_ESTADO_CIVIL          float64        0
# TP_COR_RACA              float64        0
# TP_ST_CONCLUSAO          float64        0
# TP_ANO_CONCLUIU          float64        0
# TP_ESCOLA                float64        0
# TP_PRESENCA_CN           float64        0
# TP_PRESENCA_CH           float64        0
# TP_PRESENCA_LC           float64        0
# TP_PRESENCA_MT           float64        0
# NU_NOTA_CN               float64  3185669
# NU_NOTA_CH               float64  3028969
# NU_NOTA_LC               float64  3028969
# NU_NOTA_MT               float64  3185669
# NU_NOTA_COMP1            float64  3028969
# NU_NOTA_COMP2            float64  3028969
# NU_NOTA_COMP3            float64  3028969
# NU_NOTA_COMP4            float64  3028969
# NU_NOTA_COMP5            float64  3028969
# NU_NOTA_REDACAO          float64  3028969
# Q001                      object    95966
# Q002                      object    95966
# Q003                      object    95966
# Q004                      object    95966
# Q005                     float64    95966
# Q006                      object    95966
# Q007                      object    95966
# Q008                      object    95966
# Q009                      object    95966
# Q010                      object    95966
# Q011                      object    95966
# Q012                      object    95966
# Q013                      object    95966
# Q014                      object    95966
# Q015                      object    95966
# Q016                      object    95966
# Q017                      object    95966
# Q018                      object    95966
# Q019                      object    95966
# Q020                      object    95966
# Q021                      object    95966
# Q022                      object    95966
# Q023                      object    95966
# Q024                      object    95966
# Q025                      object    95966

# %%
df = df.dropna()

# %%
info_sum_isna(df)
# Out:
#                            types  missing
# NU_INSCRICAO             float64        0
# NU_ANO                   float64        0
# NO_MUNICIPIO_RESIDENCIA   object        0
# SG_UF_RESIDENCIA          object        0
# NU_IDADE                 float64        0
# TP_SEXO                   object        0
# TP_ESTADO_CIVIL          float64        0
# TP_COR_RACA              float64        0
# TP_ST_CONCLUSAO          float64        0
# TP_ANO_CONCLUIU          float64        0
# TP_ESCOLA                float64        0
# TP_PRESENCA_CN           float64        0
# TP_PRESENCA_CH           float64        0
# TP_PRESENCA_LC           float64        0
# TP_PRESENCA_MT           float64        0
# NU_NOTA_CN               float64        0
# NU_NOTA_CH               float64        0
# NU_NOTA_LC               float64        0
# NU_NOTA_MT               float64        0
# NU_NOTA_COMP1            float64        0
# NU_NOTA_COMP2            float64        0
# NU_NOTA_COMP3            float64        0
# NU_NOTA_COMP4            float64        0
# NU_NOTA_COMP5            float64        0
# NU_NOTA_REDACAO          float64        0
# Q001                      object        0
# Q002                      object        0
# Q003                      object        0
# Q004                      object        0
# Q005                     float64        0
# Q006                      object        0
# Q007                      object        0
# Q008                      object        0
# Q009                      object        0
# Q010                      object        0
# Q011                      object        0
# Q012                      object        0
# Q013                      object        0
# Q014                      object        0
# Q015                      object        0
# Q016                      object        0
# Q017                      object        0
# Q018                      object        0
# Q019                      object        0
# Q020                      object        0
# Q021                      object        0
# Q022                      object        0
# Q023                      object        0
# Q024                      object        0
# Q025                      object        0

# %% [markdown]
# # Social Economic Status (SES)

# %%
meta = dict(zip(df.columns, df._meta.dtypes))

# %%
meta['TP_SES_INCOME'] = 'O'
df['TP_SES_INCOME'] = ''

# %%
df = df.apply(lambda x: add_ses_income(x), axis=1, meta=meta)

# %%
df.head()
# Out:
#     NU_INSCRICAO  NU_ANO NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 5   2.000031e+11  2020.0             Cerro Largo               RS       3.0
# 8   2.000068e+11  2020.0             João Pessoa               PB       5.0
# 11  2.000061e+11  2020.0               Eunápolis               BA       7.0
# 18  2.000033e+11  2020.0                  Maceió               AL       7.0
# 19  2.000060e+11  2020.0                   Belém               PA      13.0
#
#    TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 5        F              1.0          3.0              1.0              1.0
# 8        F              2.0          3.0              1.0              3.0
# 11       M              1.0          1.0              1.0              0.0
# 18       F              1.0          3.0              1.0              3.0
# 19       M              1.0          2.0              1.0              0.0
#
#     ...  Q017  Q018  Q019  Q020  Q021  Q022  Q023  Q024  Q025  TP_SES_INCOME
# 5   ...     A     A     B     B     A     D     A     B     B              E
# 8   ...     A     A     B     A     A     C     A     A     A              E
# 11  ...     B     A     B     A     A     C     A     B     B              E
# 18  ...     A     A     B     B     A     C     A     B     B              E
# 19  ...     A     A     B     B     A     C     A     A     A              E
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Points System

# %%
meta['TP_SES_POINTS'] = 'O'
df['TP_SES_POINTS'] = ''

# %%
df = df.apply(lambda x: add_ses_points(x), axis=1, meta=meta)

# %%
df.head()
# Out:
#     NU_INSCRICAO  NU_ANO NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 5   2.000031e+11  2020.0             Cerro Largo               RS       3.0
# 8   2.000068e+11  2020.0             João Pessoa               PB       5.0
# 11  2.000061e+11  2020.0               Eunápolis               BA       7.0
# 18  2.000033e+11  2020.0                  Maceió               AL       7.0
# 19  2.000060e+11  2020.0                   Belém               PA      13.0
#
#    TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 5        F              1.0          3.0              1.0              1.0
# 8        F              2.0          3.0              1.0              3.0
# 11       M              1.0          1.0              1.0              0.0
# 18       F              1.0          3.0              1.0              3.0
# 19       M              1.0          2.0              1.0              0.0
#
#     ...  Q018  Q019  Q020  Q021  Q022  Q023  Q024  Q025  TP_SES_INCOME  \
# 5   ...     A     B     B     A     D     A     B     B              E
# 8   ...     A     B     A     A     C     A     A     A              E
# 11  ...     A     B     A     A     C     A     B     B              E
# 18  ...     A     B     B     A     C     A     B     B              E
# 19  ...     A     B     B     A     C     A     A     A              E
#
#     TP_SES_POINTS
# 5              C2
# 8              DE
# 11             C2
# 18             DE
# 19             DE
#
# [5 rows x 52 columns]

# %% [markdown]
# # Save

# %%
#%%time --- Wall time: 12min 42s

#df.to_parquet('../datasets/enem_2020.parquet.gzip', engine='fastparquet', compression='gzip', write_index=False)

# %% [markdown]
# # Load parquet files

# %%
# First part
path = '../datasets/enem_2020.parquet.gzip/part.0.parquet'

df_enem_parquet = load_parquets(path, 32)

# %%
df_enem_parquet.head(5)
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  2.000031e+11  2020.0              3.0       F              1.0
# 1  2.000068e+11  2020.0              5.0       F              2.0
# 2  2.000061e+11  2020.0              7.0       M              1.0
# 3  2.000033e+11  2020.0              7.0       F              1.0
# 4  2.000060e+11  2020.0             13.0       M              1.0
#
#    TP_COR_RACA  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0          3.0              1.0              1.0        1.0
# 1          3.0              1.0              3.0        1.0
# 2          1.0              1.0              0.0        1.0
# 3          3.0              1.0              3.0        1.0
# 4          2.0              1.0              0.0        1.0
#
#   NO_MUNICIPIO_PROVA  ... Q018  Q019  Q020  Q021  Q022  Q023  Q024  Q025  \
# 0        Cerro Largo  ...    A     B     B     A     D     A     B     B
# 1        João Pessoa  ...    A     B     A     A     C     A     A     A
# 2          Eunápolis  ...    A     B     A     A     C     A     B     B
# 3             Maceió  ...    A     B     B     A     C     A     B     B
# 4              Belém  ...    A     B     B     A     C     A     A     A
#
#    TP_SES_INCOME  TP_SES_POINTS
# 0              E             C2
# 1              E             DE
# 2              E             C2
# 3              E             DE
# 4              E             DE
#
# [5 rows x 52 columns]
